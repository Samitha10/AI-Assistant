# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('product_details.csv')

# %%
data.head(50)
# Out:
#    category                                       product_name  price  \
# 0     baby                                      Baby Soap 100g      5
# 1     baby                            Baby Eau De Ceylon 100ml     19
# 2     baby                        Baby Soothing Aloe Gel 250Ml     19
# 3     baby                                  Baby Shampoo 250ml     19
# 4     baby                                     Baby Wash 250ml     19
# 5      skin  Skin-Balance – Moringa Herb – Discolouration T...     26
# 6      skin     Sal & Saffron – Vitamin E Rich – Skin Care Set     35
# 7      skin  Sal & Saffron – Vitamin E Rich – Eye Zone – Da...     18
# 8      skin  Sal & Saffron – 2-in-1 Deep Cleanser + Facial ...     21
# 9      skin  Sal & Saffron – Vitamin E Rich – Facial Cleans...     21
# 10     skin  Sal & Saffron – Vitamin E Rich – Ultra-Hydrati...     22
# 11     skin  Sal & Saffron – Vitamin E Rich – Glow Activati...     22
# ...

# %%
counts = data['category'].value_counts()

counts.to_csv('counts.txt', header=True)

# %%
section = data['section'].value_counts()
section.to_csv('section.txt', header=True)
